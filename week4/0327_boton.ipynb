# %%
/content/drive/MyDrive/Colab Notebooks/boston.csv

# %%
import pandas as pd
import numpy as np

from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split # 데이터를 train, test로 나누는 데 사용됨
from sklearn.preprocessing import StandardScaler # 데이터를 표준화하는 데 사용됨
from sklearn.tree import DecisionTreeClassifier # 결정 트리 모델을 학습시키는 데 사용됨
from sklearn.ensemble import RandomForestClassifier # 랜덤 포레스트
from sklearn.svm import SVC # 서포트 벡터 머신
from sklearn.linear_model import LogisticRegression # 로지스틱 회귀 모델
from sklearn.metrics import accuracy_score # 모델의 예측 성능 평가
# CSV 파일 읽기
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/boston.csv')

df.head()
# Out:
#    Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0           0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1           1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2           2  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3           3  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4           4  3.8462      52.0  6.281853   1.081081       565.0  2.181467
#
#    Latitude  Longitude  PRICE
# 0     37.88    -122.23  4.526
# 1     37.86    -122.22  3.585
# 2     37.85    -122.24  3.521
# 3     37.85    -122.25  3.413
# 4     37.85    -122.25  3.422

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'MedInc', 'HouseAge', 'AveRooms', 'AveBedrms',
#        'Population', 'AveOccup', 'Latitude', 'Longitude', 'PRICE'],
#       dtype='object')

# %%
print(df.count())
print(df.count().sum())
# Out:
# Unnamed: 0    20640
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# PRICE         20640
# dtype: int64
# 206400

# %%
# 2. 불필요한 열 제거
# 대신 의미 없는 순번인 'Unnamed: 0'을 제거합니다.
X = df.drop(['PRICE', 'Unnamed: 0'], axis=1)
y = df['PRICE']

# 3. 결측치 처리
# (이 데이터셋에는 'Age'가 아니라 'HouseAge'라는 컬럼명이 존재합니다.)
X['HouseAge'] = X['HouseAge'].fillna(X['HouseAge'].mean())

# 4. 문자열 → 숫자 변환 (인코딩)
# X = pd.get_dummies(X, drop_first=True)
from sklearn.model_selection import train_test_split
# 5. 데이터 분리 (학습용 75%, 테스트용 25%)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.5404128061709085
# 평균제곱근오차 0.5404128061709085
# 평균제곱근오차 0.5404128061709089

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.5403777773526163

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.2735299101226464

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# 1. 데이터 스케일링 (필수!)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 2. 모델 설정 및 학습 (스케일링된 데이터 사용)
# 여전히 느리다면 max_iter를 설정해 강제로 제한을 둘 수 있습니다.
model = SVR(kernel='linear')
model.fit(X_train_scaled, y_train)

# 3. 예측 및 평가
ry_preds = model.predict(X_test_scaled)
print('평균제곱근오차:', mean_squared_error(y_test, ry_preds))
# Out:
# 평균제곱근오차: 4.688452138519368

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['MedInc'], y_test, label='y_test')
plt.scatter(X_test['MedInc'], ry_preds, c='orange', label='ry_preds')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2612/37596958.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(10,5))
#       2 plt.scatter(X_test['MedInc'], y_test, label='y_test')
#       3 plt.scatter(X_test['MedInc'], ry_preds, c='orange', label='ry_preds')
#       4
#       5 plt.show()
#
# NameError: name 'plt' is not defined
